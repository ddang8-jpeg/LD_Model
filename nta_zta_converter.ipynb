# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
import csv

# Loading shapefile
shapefile = gpd.read_file('data/NTA map/geo_export_49ef428f-9550-420f-9953-bdb0fb30adec.shp')
# Loading cooling towerpoints
towers = pd.read_csv('data/bronx_detections.csv')

# %%
# Convert long and lat to geometric points
towers['geometry'] = towers.apply(lambda row: Point(row['longitude (deg)'], row['latitude (deg)']), axis=1)

# Convert points to GeoDataFrame
points_gdf = gpd.GeoDataFrame(towers, geometry='geometry')

# %% [markdown]
# Ensure that both the shapefile and the points are in the same coordinate reference system (CRS). If they are not, reproject one of them.

# %%
# Check the CRS of the shapefile
print(shapefile.crs)

# Reproject points if needed to match the shapefile CRS
points_gdf = points_gdf.set_crs("EPSG:4326")  # Assuming the points are in WGS84 (latitude, longitude)
points_gdf = points_gdf.to_crs(shapefile.crs)
# Out:
# EPSG:4326

# %%
# Perform spatial join
labeled = gpd.sjoin(points_gdf, shapefile, how="left", predicate="within")

# The resulting dataframe will contain the points and the corresponding labels from the shapefile
labeled
# Out:
#         id  selected  inside_boundary  meets threshold  latitude (deg)  \
# 0        0     False             True             True       40.702250
# 1        1      True             True             True       40.691670
# 2        2      True             True             True       40.691692
# 3        3      True             True             True       40.655290
# 4        4      True             True             True       40.655400
# ...    ...       ...              ...              ...             ...
# 1152  1152     False             True             True       40.684728
# 1153  1153      True             True             True       40.656292
# 1154  1154      True             True             True       40.656294
# 1155  1155     False             True             True       40.612022
# 1156  1156      True             True             True       40.585051
#
#       longitude (deg)  distance from center (m)  \
# 0          -73.979703                    7675.3
# 1          -73.988769                    7330.5
# 2          -73.988756                    7331.3
# 3          -73.912532                    1304.8
# 4          -73.912612                    1307.6
# ...               ...                       ...
# 1152       -74.007031                    8120.6
# 1153       -73.945334                    2027.0
# 1154       -73.945311                    2025.4
# 1155       -73.845034                    7776.3
# 1156       -73.901241                    7231.9
#
#                                                 address  confidence  \
# 0          1 1st Ave, Brooklyn, NY 11251, United States        0.59
# 1                  1 Boerum Pl, Brooklyn, NY 11201, USA        0.64
# 2                  1 Boerum Pl, Brooklyn, NY 11201, USA        0.62
# 3            1 Brookdale Plaza, Brooklyn, NY 11212, USA        0.89
# 4            1 Brookdale Plaza, Brooklyn, NY 11212, USA        0.86
# ...                                                 ...         ...
# 1152  Hugh L. Carey Tunnel, Brooklyn, NY 11231, Unit...        0.32
# 1153  Kings county hopital, 441 Clarkson Ave, Brookl...        0.69
# 1154  Kings county hopital, 441 Clarkson Ave, Brookl...        0.67
# 1155                  New York, NY 11234, United States        0.60
# 1156                        New York, NY, United States        0.68
#
#                         geometry  index_right  borocode  boroname countyfips  \
# 0      POINT (-73.9797 40.70225)        187.0       3.0  Brooklyn        047
# 1     POINT (-73.98877 40.69167)        184.0       3.0  Brooklyn        047
# 2     POINT (-73.98876 40.69169)        184.0       3.0  Brooklyn        047
# 3     POINT (-73.91253 40.65529)          4.0       3.0  Brooklyn        047
# 4      POINT (-73.91261 40.6554)          4.0       3.0  Brooklyn        047
# ...                          ...          ...       ...       ...        ...
# 1152  POINT (-74.00703 40.68473)        177.0       3.0  Brooklyn        047
# 1153  POINT (-73.94533 40.65629)        128.0       3.0  Brooklyn        047
# 1154  POINT (-73.94531 40.65629)        128.0       3.0  Brooklyn        047
# 1155  POINT (-73.84503 40.61202)        187.0       3.0  Brooklyn        047
# 1156  POINT (-73.90124 40.58505)          NaN       NaN       NaN        NaN
#
#      ntacode                                           ntaname    shape_area  \
# 0       BK99                        park-cemetery-etc-Brooklyn  2.287909e+08
# 1       BK38  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill  2.846257e+07
# 2       BK38  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill  2.846257e+07
# 3       BK96                              Rugby-Remsen Village  3.270695e+07
# 4       BK96                              Rugby-Remsen Village  3.270695e+07
# ...      ...                                               ...           ...
# 1152    BK33          Carroll Gardens-Columbia Street-Red Hook  4.460027e+07
# 1153    BK60                 Prospect Lefferts Gardens-Wingate  3.164212e+07
# 1154    BK60                 Prospect Lefferts Gardens-Wingate  3.164212e+07
# 1155    BK99                        park-cemetery-etc-Brooklyn  2.287909e+08
# 1156     NaN                                               NaN           NaN
#
#          shape_leng
# 0     394313.013412
# 1      32363.990305
# 2      32363.990305
# 3      30957.853395
# 4      30957.853395
# ...             ...
# 1152   60795.911417
# 1153   29580.537705
# 1154   29580.537705
# 1155  394313.013412
# 1156            NaN
#
# [1157 rows x 18 columns]

# %%
print(labeled[['latitude (deg)', 'longitude (deg)', 'ntacode']])
# Out:
#       latitude (deg)  longitude (deg) ntacode
# 0          40.702250       -73.979703    BK99
# 1          40.691670       -73.988769    BK38
# 2          40.691692       -73.988756    BK38
# 3          40.655290       -73.912532    BK96
# 4          40.655400       -73.912612    BK96
# ...              ...              ...     ...
# 1152       40.684728       -74.007031    BK33
# 1153       40.656292       -73.945334    BK60
# 1154       40.656294       -73.945311    BK60
# 1155       40.612022       -73.845034    BK99
# 1156       40.585051       -73.901241     NaN
#
# [1157 rows x 3 columns]

# %%
labeled = labeled.dropna()
labeled = labeled.loc[labeled['selected'] == True]

# Count the occurrences of values in column A using a dictionary
counts = labeled.groupby('ntacode').size().reset_index()
counts.rename(columns={'ntacode': 'NTA code', 0: 'Towers'}, inplace=True)
counts.set_index('NTA code', inplace=True)

# %% [markdown]
# Cleaning up data. Kept columns:

# %%
with open('data/cleaned_data/nta_tower_count.csv', 'w', newline='') as file:
    counts.to_csv(file)
